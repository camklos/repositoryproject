# %%
name = input(prompt="What is your name? ")
age = input(prompt="What is your age? ")
year = 2023-int(age)
print(name, ", you were born in ", year, " or ", year-1)
# Out:
# What is your name?  Brenden
# What is your age?  19
# Brenden , you were born in  2004  or  2003
